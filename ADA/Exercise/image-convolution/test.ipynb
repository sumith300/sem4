# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
from skimage import  color, data
import cv2 as cv

# %%
input = np.array([[2, 1, 2, 7, 4, 9, 5, 9, 7, 5],
                  [7, 7, 4, 4, 5, 5, 3, 9, 3, 5],
                  [0, 5, 0, 8, 1, 6, 3, 7, 8, 6],
                  [3, 6, 1, 4, 0, 1, 5, 5, 9, 2],
                  [2, 2, 9, 8, 8, 8, 0, 2, 9, 4],
                  [5, 9, 4, 7, 4, 5, 2, 0, 7, 4],
                  [4, 6, 1, 3, 4, 1, 4, 4, 4, 7],
                  [9, 4, 7, 9, 9, 9, 5, 0, 2, 4],
                  [9, 9, 9, 3, 5, 3, 7, 5, 9, 4],
                  [3, 0, 6, 3, 7, 5, 4, 0, 2, 0]])

# %%
# the kernel for edge detection
kernel=np.array([[-1,-1,-1],
                 [-1, 8,-1],
                 [-1,-1,-1]])

# %%
# the kernel for sharpening
kernel=np.array([[0,-1,0],
                  [-1, 5,-1],
                  [0,-1,0]])

# %%
convolved = ndimage.convolve(input, kernel)
print(input)
print(kernel1)
print(convolved)


#copying the input image
# Out:
# [[2 1 2 7 4 9 5 9 7 5]
#  [7 7 4 4 5 5 3 9 3 5]
#  [0 5 0 8 1 6 3 7 8 6]
#  [3 6 1 4 0 1 5 5 9 2]
#  [2 2 9 8 8 8 0 2 9 4]
#  [5 9 4 7 4 5 2 0 7 4]
#  [4 6 1 3 4 1 4 4 4 7]
#  [9 4 7 9 9 9 5 0 2 4]
#  [9 9 9 3 5 3 7 5 9 4]
#  [3 0 6 3 7 5 4 0 2 0]]
# [[ 0 -1  0]
#  [-1  5 -1]
#  [ 0 -1  0]]
# [[ -2  -7  -4  18  -5  22  -1  15  11   3]
#  [ 19  18   7  -4  11   2  -7  23 -14   6]
#  [-15  12 -18  31 -14  20  -6  10  15   9]
#  [  4  19 -14   3 -14 -14  16   2  21 -11]
#  [ -2 -16  30  12  20  26 -17  -4  23   1]
#  [  5  28  -6  16  -4  10   1 -15  18  -2]
#  [ -4  12 -15  -6   3 -17   8  12   0  16]
#  [ 19 -11  12  23  18  27   5 -16  -7   3]
#  [ 15  23  20 -11   3 -11  18   9  32   3]
#  [  0 -18  12  -4  15   6   4 -11  -1  -6]]

# %%
img = io.imread('cham.jpg')
gray_img = color.rgb2gray(img)
plt.imshow(gray_img, cmap='gray')
plt.axis('off')
plt.show()

# %%
blur = cv.GaussianBlur(gray_img,(11,11),0)
plt.imshow(blur, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(319.5), np.float64(479.5), np.float64(-0.5))

# %%
fig,axes = plt.subplots(1, 2, figsize=(10, 5))
axes[0].imshow(gray_img, cmap='gray')
axes[0].set_title('Original Image')
axes[0].axis('off')
axes[1].imshow(blur, cmap='gray')
axes[1].set_title('Blurred Image')
axes[1].axis('off')
plt.show()
